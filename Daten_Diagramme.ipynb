# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
plt.style.use({'figure.facecolor':'white'})

# %%
sheetnames=[]
with pd.ExcelFile('data/2021-04-22_Daten Diagramme.xlsx') as sheets:
    sheetnames=sheets.sheet_names

display(sheets.sheet_names)
sheetdata={sheetname:pd.read_excel('data/2021-04-22_Daten Diagramme.xlsx',sheet_name=sheetname,header=[0]) for sheetname in sheets.sheet_names}
# Out:
# ['Schmelzextraktion SZ',
#  'Pulverfeuchte',
#  'H-Gehalte Nitrogen',
#  'Kerbschlag',
#  'Magnet',
#  'UP-Zugversuch']

# %%
plt.style.use('C:\\Users\\maede\\.matplotlib\\diss_martin_arh.mplstyle')
display(sheetdata['Schmelzextraktion SZ'])
fig=plt.figure()
ax=fig.add_axes([0.25,0.166666667,0.49,0.66666667])
rage=np.arange(0,3,1)
ax.bar(-0.4,sheetdata['Schmelzextraktion SZ'].iloc[3,0+1],width=0.5,zorder=1.5,color='lightgrey',yerr=sheetdata['Schmelzextraktion SZ'].iloc[4,0+1],capsize=5,
                 alpha=1,edgecolor='black',lw=1,label=sheetdata['Schmelzextraktion SZ'].columns[0+1])
ax.bar(1,sheetdata['Schmelzextraktion SZ'].iloc[3,1+1],width=0.5,zorder=1.5,color='lightgrey',yerr=sheetdata['Schmelzextraktion SZ'].iloc[4,1+1],capsize=5,
                 alpha=1,edgecolor='black',lw=1,label=sheetdata['Schmelzextraktion SZ'].columns[1+1])
ax.bar(2.4,sheetdata['Schmelzextraktion SZ'].iloc[3,2+1],width=0.5,zorder=1.5,color='lightgrey',yerr=sheetdata['Schmelzextraktion SZ'].iloc[4,2+1],capsize=5,
                 alpha=1,edgecolor='black',lw=1,label=sheetdata['Schmelzextraktion SZ'].columns[2+1])
    #ax.set_xticklabels({i:sheetdata['Schmelzextraktion SZ'].columns[i+1]})
ax.set_xticks([-0.4,1,2.4])
ax.tick_params(axis='x',which='both',length=0)
ax.set_ylabel('Wasserstoffgehalt [ppm]')
ax.set_xlim([-1,3])
ax.set_xticklabels(sheetdata['Schmelzextraktion SZ'].columns[1:],rotation=0)
ax.set_xlabel('Schweißzusatz')
fig.savefig('Schmelzextraktion.png',dpi=500)
# Out:
#           typ        S2   S3Ni1Mo  S3Ni2,5CrMo
# 0         ppm  1.980000  3.630000     2.160000
# 1         ppm  1.330000  2.930000     1.820000
# 2         ppm  1.440000  2.770000     1.770000
# 3  Mittelwert  1.583333  3.110000     1.916667
# 4       STABW  0.347898  0.457384     0.212211

# %%
display(sheetdata['Pulverfeuchte'])
fig=plt.figure()
ax=fig.add_axes([0.20,0.16666667,0.49,0.66666667])
rage=np.arange(0,2,1)

ax.bar(2,sheetdata['Pulverfeuchte'].iloc[0,0+1],width=0.5,zorder=1.5,
           color='lightgrey',yerr=sheetdata['Pulverfeuchte'].iloc[1,0+1],capsize=5,alpha=1,edgecolor='black',lw=1)
ax.bar(0,sheetdata['Pulverfeuchte'].iloc[0,1+1],width=0.5,zorder=1.5,
           color='lightgrey',yerr=sheetdata['Pulverfeuchte'].iloc[1,1+1],capsize=5,alpha=1,edgecolor='black',lw=1)
ax.set_xticks([0,2])
ax.tick_params(axis='x',which='both',length=0)
ax.set_xlim([-1,3])
ax.set_ylabel('rel. Pulverfeuchte [%]')# H$_{2}$O
ax.set_xticklabels(['trocken','feucht'],rotation=0)
ax.set_xlabel('Pulverszustand')
fig.savefig('Pulverfeuchte.png',dpi=500)
# Out:
#                                                 name  72 h @ 10 °C, 90 % RH  \
# 0  rel. Wassergehalt [g H2O/ 100 g Pulver] bzw. r...               0.154677
# 1                                             Stabw.               0.018000
#
#    Ausgangszustand
# 0         0.036127
# 1         0.012000

# %%
display(sheetdata['H-Gehalte Nitrogen'])
fig=plt.figure()
ax=fig.add_axes([0.125,0.16666667,0.75,0.66666667])
display(len(sheetdata['H-Gehalte Nitrogen']))
rage=range(0,len(sheetdata['H-Gehalte Nitrogen']),2)
ax.tick_params(axis='x',which='both',length=0)
for i in rage:
    ax.bar(i/2,sheetdata['H-Gehalte Nitrogen'].iloc[i,3],width=0.5,zorder=1.5,
           color='lightgrey',yerr=sheetdata['H-Gehalte Nitrogen'].iloc[i+1,3],capsize=5,alpha=1,edgecolor='black',lw=1)
    ax.bar(i/2,sheetdata['H-Gehalte Nitrogen'].iloc[i,5],width=0.5,zorder=1.0,
           color='grey',yerr=sheetdata['H-Gehalte Nitrogen'].iloc[i+1,5],capsize=5,alpha=1,edgecolor='black',lw=1)
ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(sheetdata['H-Gehalte Nitrogen'].loc[::2,'label'])
ax.text(0.5,1.7,'S355N-S2',ha='center',va='center')
ax.text(2.5,1.7,'L555M-\nS3Ni1Mo',ha='center',va='center')
ax.text(4.5,1.7,'S690QL-\nS3Ni2,5CrMo',ha='center',va='center')

ax.set_ylabel('Wasserstoffgehalt [ppm]')
ax.set_xlabel('Pulverzustand')
ax.axvline(1.5,color='black')
ax.axvline(3.5,color='black')
ax.set_xlim([-0.5,5.5])
ax.set_ylim([0,2])
fig.savefig('H-Gehalte Nitrogen.png',dpi=500)
# Out:
#    powder material   name   diffppm   trapppm  complete    label
# 0     DRY        S   mean  0.323487  0.166134  0.489607  trocken
# 1     DRY        S  stabw  0.040133  0.010329  0.040105  trocken
# 2     WET        S   mean  0.632311  0.266460  0.898754   feucht
# 3     WET        S  stabw  0.047452  0.025368  0.068216   feucht
# 4     DRY        X   mean  0.272645  0.152393  0.425028  trocken
# 5     DRY        X  stabw  0.001611  0.003633  0.003448  trocken
# 6     WET        X   mean  0.648999  0.238602  0.887585   feucht
# 7     WET        X  stabw  0.072569  0.047764  0.119563   feucht
# 8     DRY        Q   mean  0.274595  0.162046  0.436630  trocken
# 9     DRY        Q  stabw  0.010343  0.028004  0.028502  trocken
# 10    WET        Q   mean  0.820236  0.301337  1.121550   feucht
# 11    WET        Q  stabw  0.075573  0.021705  0.097273   feucht
# 12

# %%
display(sheetdata['Kerbschlag'])
fig=plt.figure()
ax=fig.add_axes([0.25,0.166666667,0.3,0.66666667])
rage=np.arange(0,2,1)
ax.bar(0,sheetdata['Kerbschlag'].iloc[0,0+2],width=0.8,zorder=1.5,color='lightgrey',yerr=sheetdata['Kerbschlag'].iloc[1,0+2],capsize=5,
                 alpha=1,edgecolor='black',lw=1)
ax.bar(2,sheetdata['Kerbschlag'].iloc[0,1+2],width=0.8,zorder=1.5,color='lightgrey',yerr=sheetdata['Kerbschlag'].iloc[1,1+2],capsize=5,
                 alpha=1,edgecolor='black',lw=1)
ax.set_ylabel('Schlagenergie KV$_{8}$ [J]')
ax.set_xlabel('Pulverzustand')
ax.tick_params(axis='x',which='both',length=0)
ax.set_xlim([-1,3])
ax.set_xticks([0,2])
ax.set_xticklabels(sheetdata['Kerbschlag'].columns[2:],rotation=0)
fig.savefig('Kerbschlag.png',dpi=500)
# Out:
#     type                   name     trocken      feucht
# 0   mean  Schlagenergie KV8 [J]  136.250000  149.000000
# 1  Stabw                    NaN    5.560276    7.874008

# %%
display(sheetdata['Magnet'])
fig=plt.figure()
ax=fig.add_axes([0.20,0.16666667,0.3,0.66666667])
rage=np.arange(0,2,1)

ax.bar(0,sheetdata['Magnet'].iloc[1,0+1],width=0.8,zorder=1.5,color='lightgrey',yerr=sheetdata['Magnet'].iloc[2,0+1],capsize=5,
                 alpha=1,edgecolor='black',lw=1)
ax.bar(2,sheetdata['Magnet'].iloc[1,0+1],width=0.8,zorder=1.5,color='lightgrey',yerr=sheetdata['Magnet'].iloc[2,1+1],capsize=5,
                 alpha=1,edgecolor='black',lw=1)
ax.tick_params(axis='x',which='both',length=0)
ax.set_ylabel('unmagnetischer\nAnteil [%]')
ax.set_xlabel('Pulverzustand')
ax.tick_params(axis='x',which='both',length=0)
ax.set_xlim([-1,3])
ax.set_xticks([0,2])
ax.set_xticklabels(['trocken','feucht'],rotation=0)
fig.savefig('Magnet.png',dpi=500)
# Out:
#                               name  S690QL-S3Ni2,5CrMo (Pulver trocken)  \
# 0    Anteil magnetischer Phase [%]                            96.095000
# 1  Anteil unmagnetischer Phase [%]                             3.905000
# 2                  stabw unmagnet.                             1.619275
#
#    S690QL-S3Ni2,5CrMo (Pulver feucht)
# 0                           94.995000
# 1                            5.005000
# 2                            0.275772
